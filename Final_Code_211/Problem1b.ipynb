# %% [markdown]
# # Example File for Final Project

# %% [markdown]
# This notebook provides an example to generate a TRISO cylindrical compact placed in an hexagonal graphite matrix.  The data provided does not match the geometry of the project so this should be used as a guide only.

# %%
# %matplotlib inline
import openmc
import openmc.deplete
import matplotlib.pyplot as plt

# %%
openmc.config['cross_sections'] = '/home/ralitsam/endfb-vii.1-hdf5/cross_sections.xml'

# %%
fuel = openmc.Material(name='fuel')
fuel.add_nuclide('U238', 0.7502, 'wo')
fuel.add_nuclide('U235', 0.1376, 'wo')
fuel.add_nuclide('O16', 0.0897, 'wo')
fuel.add_nuclide('C0', 0.0224, 'wo')
fuel.set_density('g/cc', 10.5)

buff = openmc.Material(name='Buffer')
buff.add_nuclide('C0', 1.0, 'wo')
buff.set_density('g/cm3', 1.0)

iPyC = openmc.Material(name='iPyC')
iPyC.add_nuclide('C0', 1.0, 'wo')
iPyC.set_density('g/cm3', 1.9)

oPyC = openmc.Material(name='oPyC')
oPyC.add_nuclide('C0', 1.0, 'wo')
oPyC.set_density('g/cm3', 1.9)

SiC = openmc.Material(name='SiC')
SiC.add_nuclide('C0', 0.5, 'wo')
SiC.add_element('Si', 0.5, 'wo')
SiC.set_density('g/cm3', 3.2)

coolant = openmc.Material(name='coolant')
#FLiBe
coolant.add_nuclide('Li6', 0.010605)
coolant.add_nuclide('Li7', 0.130795)
coolant.add_nuclide('Be9',0.0909)
coolant.add_nuclide('F19',0.7677)
coolant.set_density('g/cm3',1.925)

# %%
graphite = openmc.Material(name='moderator')
graphite.add_nuclide('C0',  0.99998985, 'wo')
graphite.add_nuclide('B10', 0.00000015, 'wo')
graphite.add_nuclide('N14', 0.00001, 'wo')
graphite.set_density('g/cc', 1.6335)

# %%
materials_file = openmc.Materials([fuel, graphite, buff, iPyC, oPyC, SiC,coolant])
materials_file.export_to_xml()

# %%
fuel.temperature = 1000
buff.temperature = 900
iPyC.temperature = 900
oPyC.temperature = 900
SiC.temperature = 900
coolant.temperature = 900
graphite.temperature = 900

# %% [markdown]
# This block defines a fuel radius and a slightly smaller compact radius to avoid situations where TRISOs would be cut by the boundary.

# %%
top = openmc.ZPlane(surface_id=4, z0=+1, boundary_type='periodic')
bottom = openmc.ZPlane(surface_id=5, z0=-1, boundary_type='periodic') 

# Geometry definitions
fuel_radius = openmc.ZCylinder(surface_id=1, r=0.635) 
coolant_radius = openmc.ZCylinder(surface_id=2, r=0.35) 

compact_radius = openmc.ZCylinder(surface_id=6, r=0.635) 

top_compact = openmc.ZPlane(surface_id=7, z0=+0.999)
bottom_compact = openmc.ZPlane(surface_id=8, z0=-0.999) 

region = -compact_radius & -top_compact & +bottom_compact

fuel_region = -fuel_radius
moder_fuel = +fuel_radius
coolant_region = -coolant_radius 
moder_coolant = +coolant_radius 
 
fuel_cell = openmc.Cell(cell_id=1, fill=fuel, region=fuel_region)
moder_fuel_cell = openmc.Cell(cell_id=2, fill=graphite, region=moder_fuel)
graphite_cell = openmc.Cell(cell_id=3, fill=graphite)

coolant_cell = openmc.Cell(cell_id=4, fill=coolant, region=coolant_region)
moder_coolant_cell = openmc.Cell(cell_id=5, fill=graphite, region=moder_coolant)

# %% [markdown]
# This block creates a TRISO universe.

# %%
# Create TRISO universe
spheres = [openmc.Sphere(r=1e-4*r)
           for r in [212.5, 312.5, 347.5, 382.5]]
#spheres = [openmc.Sphere(r=r)
 #          for r in [0.02125, 0.03125, 0.03475, 0.03825]]
cells = [openmc.Cell(fill=fuel, region=-spheres[0]),
         openmc.Cell(fill=buff, region=+spheres[0] & -spheres[1]),
         openmc.Cell(fill=iPyC, region=+spheres[1] & -spheres[2]),
         openmc.Cell(fill=SiC, region=+spheres[2] & -spheres[3]),
         openmc.Cell(fill=oPyC, region=+spheres[3])]
triso_univ = openmc.Universe(cells=cells)

# %% [markdown]
# This block places spheres of a given size in a region with a user defined packing fraction.  As the packing fraction gets larger, the run time increases substantially.

# %%
outer_radius = 422.5*1e-4
#print(domain.volume)
centers = openmc.model.pack_spheres(radius=outer_radius, region=region, pf=0.35)

# %% [markdown]
# This block assigns a triso universe to each sphere.

# %%
trisos = [openmc.model.TRISO(outer_radius, triso_univ, center) for center in centers]

# %% [markdown]
# This block creates a lattice over the TRISO region for acceleration purposes.  A virtual mesh is added and a list of TRISOs in each mesh cell is calculated.  Thus, when in a given cell, the nearest neighbor search is limited to surfaces in the mesh.

# %%
lower_left, upper_right = fuel_cell.region.bounding_box
lower_left[2] = -1.0
upper_right[2] = 1.0
shape = (3, 3, 3)
pitch = (upper_right - lower_left)/shape
lattice = openmc.model.create_triso_lattice(
    trisos, lower_left, pitch, shape, graphite)

fuel_cell.fill = lattice

# %%
fuel_u = openmc.Universe(universe_id=1001, cells=(fuel_cell,moder_fuel_cell))
graphite_u = openmc.Universe(universe_id=1002, cells=[graphite_cell])
coolant_u = openmc.Universe(universe_id=1005, cells=[coolant_cell,moder_coolant_cell])

# %%
inner = [coolant_u]
outer = [coolant_u,fuel_u,coolant_u,fuel_u,coolant_u,fuel_u]

# %% [markdown]
# An hexagonal lattice is defined with a fuel universe surrounded by a graphite universe.

# %%
hex_lat = openmc.HexLattice(lattice_id=1003, name='assembly')
hex_lat.center = (0., 0.)
hex_lat.pitch = (1.8796,)
hex_lat.orientation = 'x'
hex_lat.outer = graphite_u
hex_lat.universes = [outer, inner]

# %% [markdown]
# An hexagonal bounding box is defined around the lattice.

# %%
# Create the prism that will contain the lattice
outer_surface = openmc.model.hexagonal_prism(edge_length=2.8194, orientation='x', boundary_type='periodic')
# Out:
# /home/ralitsam/.conda/envs/openmc-env/lib/python3.12/site-packages/openmc/model/funcs.py:124: FutureWarning: The hexagonal_prism(...) function has been replaced by the HexagonalPrism(...) class. Future versions of OpenMC will not accept hexagonal_prism.
#   warn("The hexagonal_prism(...) function has been replaced by the "

# %%
# Fill a cell with the lattice. This cell is filled with the lattice and contained within the prism.
main_assembly = openmc.Cell(cell_id=7000, fill=hex_lat, region=outer_surface & -top & +bottom)

# Create a universe that contains both 
root = openmc.Universe(cells=[main_assembly])

# %%
root.plot(origin = (0,0,0), pixels=(200, 200), width = (6.,6.), color_by = 'material')
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %%
geom = openmc.Geometry(root)
geom.export_to_xml()

# %%
# OpenMC simulation parameters

lower_left = [-3, -3, -1]
upper_right = [3, 3, 1]
uniform_dist = openmc.stats.Box(lower_left, upper_right)
src = openmc.IndependentSource(space=uniform_dist)#, constraints={'fissionable': True})

settings = openmc.Settings()
settings.source = src
settings.batches = 100
settings.inactive = 25
settings.particles = 2000
settings.temperature = {'method': 'interpolation','range':(293.15,1923.15)}

settings.export_to_xml()

# %%
# %matplotlib inline
import openmc.examples
import numpy as np
import matplotlib.pyplot as plt

# %%
model = openmc.examples.pwr_pin_cell()

# %%
model.tallies
# Out:
# []

# %%
# Create equal-lethargy energies to put in filter
energies = np.logspace(np.log10(1e-5), np.log10(20.0e6), 501)
e_filter = openmc.EnergyFilter(energies)

# Create tally with energy filter
tally = openmc.Tally()
tally.filters = [e_filter]
tally.scores = ['flux']

# Set model tallies
model.tallies = [tally]

# %%
openmc.mgxs.GROUP_STRUCTURES.keys()
# Out:
# dict_keys(['CASMO-2', 'CASMO-4', 'CASMO-8', 'CASMO-16', 'CASMO-25', 'CASMO-40', 'VITAMIN-J-42', 'SCALE-44', 'MPACT-51', 'MPACT-60', 'MPACT-69', 'CASMO-70', 'XMAS-172', 'VITAMIN-J-175', 'SCALE-252', 'TRIPOLI-315', 'SHEM-361', 'CCFE-709', 'UKAEA-1102', 'ECCO-1968'])

# %%
model.tallies
# Out:
# [Tally
#  	ID             =	1
#  	Name           =
#  	Filters        =	EnergyFilter
#  	Nuclides       =
#  	Scores         =	['flux']
#  	Estimator      =	None
#  	Multiply dens. =	True]

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-05-16 09:19:02
#    MPI Processes | 1
#   OpenMP Threads | 2
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading U235 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading O16 from /home/ralitsam/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading C0 from /home/ralitsam/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading Li6 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Li6.h5
#  Reading Li7 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Li7.h5
#  Reading Be9 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Be9.h5
#  Reading F19 from /home/ralitsam/endfb-vii.1-hdf5/neutron/F19.h5
#  Reading B10 from /home/ralitsam/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading N14 from /home/ralitsam/endfb-vii.1-hdf5/neutron/N14.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.50445
#         2/1    0.51750
#         3/1    0.51038
#         4/1    0.51894
#         5/1    0.49227
#         6/1    0.49255
#         7/1    0.50328
#         8/1    0.50434
#         9/1    0.50265
#        10/1    0.52118
#        11/1    0.52512
#        12/1    0.48472
#        13/1    0.49783
#        14/1    0.50718
#        15/1    0.48785
#        16/1    0.54894
#        17/1    0.52926
#        18/1    0.52673
#        19/1    0.50962
#        20/1    0.52112
#        21/1    0.51584
#        22/1    0.51951
#        23/1    0.50694
#        24/1    0.52145
#        25/1    0.52122
#        26/1    0.51118
#        27/1    0.49806    0.50462 +/- 0.00656
#        28/1    0.52822    0.51249 +/- 0.00873
#        29/1    0.52349    0.51524 +/- 0.00676
#        30/1    0.50705    0.51360 +/- 0.00548
#        31/1    0.49861    0.51110 +/- 0.00513
#        32/1    0.53380    0.51434 +/- 0.00541
#        33/1    0.51542    0.51448 +/- 0.00469
#        34/1    0.50735    0.51369 +/- 0.00421
#        35/1    0.50494    0.51281 +/- 0.00387
#        36/1    0.51129    0.51267 +/- 0.00350
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0464e+01 seconds
#    Reading cross sections          = 4.3105e+00 seconds
#  Total time in simulation          = 1.4429e+03 seconds
#    Time in transport only          = 1.4420e+03 seconds
#    Time in inactive batches        = 3.2712e+02 seconds
#    Time in active batches          = 1.1158e+03 seconds
#    Time synchronizing fission bank = 4.3188e-02 seconds
#      Sampling source sites         = 3.5212e-02 seconds
#      SEND/RECV source sites        = 6.2475e-03 seconds
#    Time accumulating tallies       = 7.7906e-01 seconds
#    Time writing statepoints        = 4.5055e-02 seconds
#  Total time for finalization       = 4.8693e-03 seconds
#  Total time elapsed                = 1.4536e+03 seconds
#  Calculation Rate (inactive)       = 152.851 particles/second
#  Calculation Rate (active)         = 134.43 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.51121 +/- 0.00192
#  k-effective (Track-length)  = 0.51003 +/- 0.00134
#  k-effective (Absorption)    = 0.51106 +/- 0.00200
#  Combined k-effective        = 0.51030 +/- 0.00124
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
fuel.volume = len(trisos)*4/3*3.1416*(212.5*1e-4)**3

# %%
# Create depletion "operator"
model = openmc.Model(geometry=geom, materials=materials_file, settings=settings)
op = openmc.deplete.CoupledOperator(model, "chain_casl_pwr.xml")

# Perform simulation using the predictor algorithm
time_steps = [1.0, 2.0, 10.0, 20.0, 30.0]  # days
power = 1000  
integrator = openmc.deplete.PredictorIntegrator(op, time_steps, power, timestep_units='d')
integrator.integrate()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-05-16 09:43:17
#    MPI Processes | 1
#   OpenMP Threads | 2
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /home/ralitsam/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading U235 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading C0 from /home/ralitsam/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading Be9 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Be9.h5
#  Reading F19 from /home/ralitsam/endfb-vii.1-hdf5/neutron/F19.h5
#  Reading Li6 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Li6.h5
#  Reading Li7 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Li7.h5
#  Reading B10 from /home/ralitsam/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading N14 from /home/ralitsam/endfb-vii.1-hdf5/neutron/N14.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
# [openmc.deplete] t=0.0 s, dt=86400.0 s, source=1000
#  Reading B11 from /home/ralitsam/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading Br81 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Br81.h5
#  Reading Kr82 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Kr82.h5
#  Reading Kr83 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Kr83.h5
#  Reading Kr84 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Kr84.h5
#  Reading Kr85 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Kr85.h5
#  Reading Kr86 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Kr86.h5
#  Reading Sr89 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Sr89.h5
#  Reading Sr90 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Sr90.h5
#  Reading Y89 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Y89.h5
#  Reading Y90 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Y90.h5
#  Reading Y91 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Y91.h5
#  Reading Zr90 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr93 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr93.h5
#  Reading Zr94 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr95 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr95.h5
#  Reading Zr96 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Nb95 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Nb95.h5
#  Reading Mo92 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo92.h5
#  WARNING: Negative value(s) found on probability table for nuclide Nb95 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Nb95 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Nb95 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Nb95 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Nb95 at 1200K
#  Reading Mo94 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo94.h5
#  Reading Mo95 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo95.h5
#  Reading Mo96 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo96.h5
#  Reading Mo97 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo97.h5
#  Reading Mo98 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo98.h5
#  Reading Mo99 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo99.h5
#  WARNING: Negative value(s) found on probability table for nuclide Mo99 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Mo99 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Mo99 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Mo99 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Mo99 at 1200K
#  WARNING: Negative value(s) found on probability table for nuclide Mo99 at 2500K
#  Reading Mo100 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Mo100.h5
#  Reading Tc99 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Tc99.h5
#  Reading Ru100 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru100.h5
#  Reading Ru101 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru101.h5
#  Reading Ru102 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru102.h5
#  Reading Ru103 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru103.h5
#  Reading Ru104 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru104.h5
#  Reading Ru105 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru105.h5
#  Reading Ru106 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ru106.h5
#  Reading Rh103 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Rh103.h5
#  Reading Rh105 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Rh105.h5
#  Reading Pd104 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pd104.h5
#  Reading Pd105 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pd105.h5
#  Reading Pd106 from /home/ralitsam/endfb-vii.1-hdf5/neutron/
from /home/ralitsam/endfb-vii.1-hdf5/neutron/Eu154.h5
#  Reading Eu155 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Eu155.h5
#  Reading Eu156 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Eu156.h5
#  WARNING: Negative value(s) found on probability table for nuclide Eu156 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Eu156 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Eu156 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Eu156 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Eu156 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Eu156 at
#           2500K
#  Reading Eu157 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Eu157.h5
#  Reading Gd152 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd152.h5
#  Reading Gd154 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd154.h5
#  Reading Gd155 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd155.h5
#  Reading Gd156 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd156.h5
#  Reading Gd157 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd157.h5
#  Reading Gd158 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd158.h5
#  Reading Gd160 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Gd160.h5
#  Reading Tb159 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Tb159.h5
#  Reading Tb160 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Tb160.h5
#  Reading Dy160 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Dy160.h5
#  Reading Dy161 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Dy161.h5
#  Reading Dy162 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Dy162.h5
#  Reading Dy163 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Dy163.h5
#  Reading Dy164 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Dy164.h5
#  Reading Ho165 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ho165.h5
#  Reading Er162 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Er162.h5
#  Reading Er164 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Er164.h5
#  Reading Er166 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Er166.h5
#  Reading Er167 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Er167.h5
#  Reading Er168 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Er168.h5
#  Reading Er170 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Er170.h5
#  Reading Tm169 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Tm169.h5
#  Reading Tm170 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Tm170.h5
#  Reading Hf174 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading Ta181 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ta181.h5
#  Reading Ta182 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Ta182.h5
#  Reading Th230 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Th230.h5
#  Reading Th231 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Th231.h5
#  Reading Th232 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Th232.h5
#  Reading Th233 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Th233.h5
#  Reading Th234 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Th234.h5
#  Reading Pa231 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pa231.h5
#  Reading Pa232 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pa232.h5
#  Reading Pa233 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pa233.h5
#  Reading U232 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U232.h5
#  Reading U233 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U233.h5
#  Reading U234 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U236 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U237 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U237.h5
#  Reading U239 from /home/ralitsam/endfb-vii.1-hdf5/neutron/U239.h5
#  Reading Np236 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Np236.h5
#  Reading Np237 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Np237.h5
#  Reading Np238 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Np238.h5
#  Reading Np239 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Np239.h5
#  Reading Pu236 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu236.h5
#  Reading Pu237 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu237.h5
#  Reading Pu238 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu238.h5
#  Reading Pu239 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu239.h5
#  Reading Pu240 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu240.h5
#  Reading Pu241 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu241.h5
#  Reading Pu242 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu242.h5
#  Reading Pu243 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Pu243.h5
#  Reading Am241 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Am241.h5
#  Reading Am242 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Am242.h5
#  Reading Am242_m1 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Am242_m1.h5
#  Reading Am243 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Am243.h5
#  Reading Am244 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Am244.h5
#  Reading Am244_m1 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Am244_m1.h5
#  Reading Cm242 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Cm242.h5
#  Reading Cm243 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Cm243.h5
#  Reading Cm244 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Cm244.h5
#  Reading Cm245 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Cm245.h5
#  Reading Cm246 from /home/ralitsam/endfb-vii.1-hdf5/neutron/Cm246.h5
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================

# %%
# Open results file
results = openmc.deplete.ResultsList.from_hdf5("depletion_results.h5")

# Obtain K_eff as a function of time
time, keff = results.get_eigenvalue()

# Obtain U235 concentration as a function of time
time, n_U235 = results.get_atoms('1', 'U235')

###############################################################################
#                            Generate plots
###############################################################################

days = 24*60*60
plt.figure()
plt.plot(time/days, keff[:,0], label="K-effective")
plt.xlabel("Time (days)")
plt.ylabel("Keff")
plt.show()

plt.figure()
plt.plot(time/days, n_U235, label="U235")
plt.xlabel("Time (days)")
plt.ylabel("n U5 (-)")
plt.show()

# %%
print(results)

# %%
with openmc.StatePoint(sp_path) as sp:
    t = sp.tallies[tally.id]
    flux500_mean = t.mean.ravel()
    flux500_unc = t.std_dev.ravel()
